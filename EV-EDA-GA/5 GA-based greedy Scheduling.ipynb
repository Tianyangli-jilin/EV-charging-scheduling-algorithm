# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy
import random
import time

class EVCSIndividual:

    '''
    individual of demand oriented method
    '''
    def __init__(self,data,ev_ct,ec_cp,ev_n):

        self.data=data  #候选数据
        self.evcs=np.zeros(ev_n)  #每个充电站的车数
        self.individual=[]
        self.fitness=[]
        self.ev_ct=ev_ct
        self.ev_cp=ec_cp
        self.ev_n=ev_n

    def GenerateIndividual(self):
        '''
        generate a random chromsome for genetic algorithm
        '''
        gene = list()    #问题的解，基因，种群中的个体：[0，...，city_size]
        for i in range(len(self.data)):
            ind=random.choices(self.data[i])
            copy_ind=copy.deepcopy(ind[0])
            copy_ind.append(i)
            gene.append(copy_ind)
        random.shuffle(gene)
        self.individual=gene

    def calculateFitness(self,cd_n=5):
        '''
        calculate the fitness of the indiviual
        '''
        ev_n=np.zeros((self.ev_n,cd_n))  #单位时间内每个电桩充电车数
        cd_wt=np.zeros((self.ev_n,cd_n)) #充电桩工作总时间
        cd_st=np.zeros((self.ev_n,cd_n)) #充电桩空闲时间
        st=0.   #电桩空闲总时间  
        qt=0.   #电车排队总时间 
        tt=0.   #充电总时间 到充电桩时间+排队时间+充电时间     
        cost=0. #充电总成本成本
        n=[]  
        x_n=0
        for i in range(len(self.individual)): #len(self.indiviual)
            cost+=self.individual[i][1]+self.ev_cp[self.individual[i][0]]*self.ev_ct[self.individual[i][2]]
            k=int(self.evcs[self.individual[i][0]]%cd_n)
            self.evcs[self.individual[i][0]]+=1
            if cd_wt[self.individual[i][0]][k]<60:
                ev_n[self.individual[i][0]][k]+=1
            if self.individual[i][1]<cd_wt[self.individual[i][0]][k]:
                tt+=cd_wt[self.individual[i][0]][k]+self.ev_ct[self.individual[i][0]]
                qt+=cd_wt[self.individual[i][0]][k]-self.individual[i][1]
                cd_wt[self.individual[i][0]][k]=cd_wt[self.individual[i][0]][k]+self.ev_ct[self.individual[i][0]]
                x_n+=1
            else:
                tt+=self.individual[i][1]+self.ev_ct[self.individual[i][0]]
                st+=self.individual[i][1]-cd_wt[self.individual[i][0]][k]
                cd_st[self.individual[i][0]][k]+=self.individual[i][1]-cd_wt[self.individual[i][0]][k]
                cd_wt[self.individual[i][0]][k]=self.individual[i][1]+self.ev_ct[self.individual[i][0]]
        revnue=0.
        t_ev_n=0
        t_st_v=0
        for i in range(self.ev_n):
            for j in range(cd_n):
                revnue+=(cd_wt[i][j]-cd_st[i][j])*self.ev_cp[i]
                t_ev_n+=ev_n[i][j]
                t_st_v+=cd_st[i][j]
        
        n.append(revnue)      #总收益  
        n.append(cost)        #总成本
        n.append(tt)          #总时间
        n.append(qt)          #总排队时间
        n.append(st)          #总空闲时间
        n.append(t_ev_n)      #单位时间每个充电桩充电电车总数
        self.fitness=np.array(n)

class GeneticAlgorithm:

    def __init__(self, t_c_l, ev_ct, ev_cp, n,c_rate=0.7, m_rate=0.3, pop_size=200, maxnum=200):
        self.pop_size = pop_size#50
        self.fitness = np.zeros(self.pop_size)#Pop_size 为50，种群个数，应该修改为参数，可传递任意种群个数
        self.c_rate = c_rate #交叉率，0.7，修改为可变参数
        self.m_rate = m_rate #变异率，0.05，修改为
        self.maxiternum = maxnum# 最大迭代次数
        self.population=[]
        self.bestfitness=0.   #最好的适应值
        self.besttruefitness=[] # 最好的真适应值
        self.bestIndex=0
        self.bestgene=np.array([])
        #self.dw = Draw()    #绘图类
        self.trace = np.zeros((self.maxiternum, 2))
        self.avefitness=0.
        self.data=t_c_l
        self.ev_ct=ev_ct
        self.ev_cp=ev_cp
        self.cs_n=n
        self.bestindividual=[]   #最好的个体
    
    def initialize(self):
        '''
        initialize the population of GA
        '''
        for i in range(0, int(self.pop_size)):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            self.population.append(ind)    
        
    def evaluation(self):
        '''
        evaluation the fitness of the population
        '''
        for i in range(0, int(self.pop_size)):
            self.population[i].calculateFitness()
            self.fitness[i] = 0.3*(self.population[i].fitness[3]/40000)+0.4*(self.population[i].fitness[4]/3000)+0.3*(1-self.population[i].fitness[5]/899)
            
    def selection(self):
        for i in range(self.pop_size):
            if i != self.bestIndex and self.fitness[i] > self.avefitness:
                pi = self.cross(self.population[self.bestIndex].individual, self.population[i].individual)
                self.population[i].individual= self.mutate(pi)
                self.population[i].individual=sorted(self.population[i].individual, key=(lambda x: [x[0],x[1]]))
                self.population[i].calculateFitness()
                self.fitness[i] = 0.3*(self.population[i].fitness[3]/40000)+0.4*(self.population[i].fitness[4]/3000)+0.3*(1-self.population[i].fitness[5]/899)
    
    def crossoverMutation(self):
         for j in range(self.pop_size):
                r = np.random.randint(0, self.pop_size - 1)
                if j != r:
                    nind = self.cross(self.population[j].individual, self.population[r].individual)    #交叉种群中第j,r个体的基因
                    self.population[j].individual = self.mutate(nind)    #突变种群中第j个体的基因
                    self.population[j].calculateFitness()
                    self.fitness[j] = 0.3*(self.population[j].fitness[3]/40000)+0.4*(self.population[j].fitness[4]/3000)+0.3*(1-self.population[j].fitness[5]/899)
       
    def cross(self, parent1, parent2):
        """交叉p1,p2的部分基因片段"""
        if np.random.rand() > self.c_rate:
            return parent1
        index1 = np.random.randint(0, len(parent1) - 1)
        index2 = np.random.randint(index1,  len(parent1)- 1)
        tempGene = parent2[index1:index2]  # 交叉的基因片段
        tempGene_t = pd.DataFrame(tempGene,columns=["0","1","2"])
        tempGene_c = list(tempGene_t["2"])
        newGene = []
        p1len = 0
        for g in parent1:
            if p1len == index1:
                newGene.extend(tempGene)  # 插入基因片段
            if g[2] not in tempGene_c:
                newGene.append(g)
            p1len += 1
        
        if len(newGene)!=len(parent1):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            return ind.individual
        
        return newGene
    
    def mutate(self,gene):
        """突变"""
        if np.random.rand() > self.m_rate:
            return gene
        index1 = np.random.randint(0, len(gene) - 1)
        index2 = np.random.randint(index1, len(gene) - 1)
        newGene = self.reverse_gen(gene, index1, index2)
        if len(newGene)!=len(gene):
            ind = EVCSIndividual(self.data,self.ev_ct,self.ev_cp,self.cs_n)
            ind.GenerateIndividual()
            return ind.individual
        return newGene
    
    def reverse_gen(self, gen, i, j):
        #函数：翻转基因中i到j之间的基因片段
        if i >= j:
            return gen
        if j > len(gen) - 1:
            return gen
        parent1 = copy.deepcopy(gen)
        tempGene = parent1[i:j]
        parent1[i:j]=tempGene[::-1]
        return parent1
    
    def solve(self):
        self.t = 0
        self.initialize()
        self.evaluation()
        self.bestfitness = np.min(self.fitness)
        self.bestIndex = np.argmin(self.fitness)
        self.bestgene = copy.deepcopy(self.population[self.bestIndex])
        self.besttruefitness=self.population[self.bestIndex].fitness
        self.bestindividual=self.population[self.bestIndex].individual
        self.avefitness = np.mean(self.fitness)
        self.trace[self.t, 0] = self.fitness[self.bestIndex]
        self.trace[self.t, 1] = self.avefitness
        print("%d次迭代: 适应值:%f,平均适应值:%f,最优结果:%s" % (
            self.t, self.trace[self.t, 0], self.trace[self.t, 1],str(self.bestgene.fitness)))

        while self.t < self.maxiternum - 1:
            self.t += 1
            self.selection()
            self.crossoverMutation()
            localbest = np.min(self.fitness)
            self.bestIndex = np.argmin(self.fitness)
            if localbest<self.bestfitness:
                self.bestfitness=localbest
                self.besttruefitness=self.population[self.bestIndex].fitness
                self.bestindividual=self.population[self.bestIndex].individual
            self.bestgene = copy.deepcopy(self.population[self.bestIndex])
            self.avefitness = np.mean(self.fitness)            
            self.trace[self.t, 0] = self.fitness[self.bestIndex]
            self.trace[self.t, 1] = self.avefitness
            print("%d次迭代: 适应值:%f,平均适应值:%f,最优结果:%s" % (
                self.t, self.trace[self.t, 0], self.trace[self.t, 1],str(self.bestgene.fitness)))
        print("True Best Fitness:",self.besttruefitness)
        print("Best Fitness:",self.bestfitness)
        print("Average of queuing time (minute):",self.besttruefitness[3]/899)
        print("Average of idle time (minute):",self.besttruefitness[4]/170)
        print("Number of charged EV within an hour:",int(self.besttruefitness[5]))
        print("Total cost of all EV:",self.besttruefitness[1])
        print("Total revenue of EVCS:",self.besttruefitness[0])   
        
def main():
    '''读取充电站数据'''
    data = pd.read_csv("chargingstations.csv", delimiter=";", header=None).values  #读取34省市数据，以';'分割，dataframe
    cities = data[:, 1:]# 0行至最后一行，1列至最后一列
    cities_name = data[:, 0] #0行至最后一行，第0列
    city_size = data.shape[0]# shape属性返回包含行和列的元组
    locations = np.arange(cities.shape[0])    #问题的解，基因，种群中的个体：[0，...，city_size]

    ev_data_1000= pd.read_csv('ev_data_1000.csv').values 
    ev_x=ev_data_1000[:, 1:2]
    ev_x=[j for i in ev_x for j in i]
    ev_y=ev_data_1000[:, 2:3]
    ev_y=[j for i in ev_y for j in i]
    ev_ld=ev_data_1000[:, 3:4]
    ev_ld=[j for i in ev_ld for j in i]
    ev_ct=ev_data_1000[:, 4:5]
    ev_ct=[j for i in ev_ct for j in i]
    ev_cp_34= pd.read_csv('ev_cp_34.csv').values 
    ev_cp=ev_cp_34[:,1:]
    ev_cp=[j for i in ev_cp for j in i]
    
    '''电车候选电站'''
    t_c_l=[] #每个电车的候选充电站
    for i in range(1000):
        c_l=[]
        for j in range(34):
            d=np.sqrt((ev_x[i] - cities[j][0]) ** 2 + (ev_y[i] - cities[j][1]) ** 2)
            #d=ct_distance(ev_x[i],ev_y[i],cities[j])
            if d<ev_ld[i]:
                c=[]
                c.append(int(j))      # 充电站序号
                c.append(d)      # 距离充电站距离，也是行驶时间
                c_l.append(c)
        t_c_l.append(c_l)        

    for i in range(len(t_c_l)-1,-1,-1):
        if t_c_l[i]==[]:
            del ev_x[i]
            del ev_y[i]
            del ev_ld[i]
            del ev_ct[i]
            del t_c_l[i]
    GA=GeneticAlgorithm(t_c_l,ev_ct,ev_cp,len(cities))
    GA.solve()
    
        
#目前最优[ 16575.94745795 175006.78616601  55609.61504463  30785.9283487   2206.67604534    634.        ]
#适应值:0.594212,平均适应值:0.659067,最优结果:[ 16770.97487788 171025.98243471  55252.89521337  30548.93880873  2089.99381702    640.        ]
#适应值:0.508712,平均适应值:0.521612,最优结果:[ 16763.10019171 170352.63143501  53207.77215977  28552.77795326  1608.58002773    659.        ]
#适应值:0.507338,平均适应值:0.526123,最优结果:[ 16759.53057865 174122.93111212  52971.02862662  28044.18074583  1671.93032886    677.        ]
#适应值:0.318232,平均适应值:0.318232,最优结果:[ 16665.83843136 175328.5014536   47437.33551609  22497.46944712  675.75942351    721. ]       ]
#适应值:0.315828,平均适应值:0.378350,最优结果:[ 16533.31368097 174995.88255584  46663.01202116  21854.45136753  741.45495666    740.   ]     ]
#适应值:0.307763,平均适应值:0.376329,最优结果:[ 16589.821804   171644.80267732  46448.66209076  21793.67946582  664.36665068    732.        ]
if __name__ == '__main__':
    start=time.time()
    main()
    end=time.time()
    print("Time consuming:",end-start)
# Out:
# 0次迭代: 适应值:0.602554,平均适应值:0.657181,最优结果:[17069.32906133 28481.51326506 56728.09605272 31882.44360989
#   2022.4826816    618.        ]
# 1次迭代: 适应值:0.348783,平均适应值:0.547501,最优结果:[16642.96088665 28472.25445223 49366.91125328 24606.36987963
#    746.22455674   705.        ]
# 2次迭代: 适应值:0.340703,平均适应值:0.420902,最优结果:[16632.88854835 28343.67676465 49031.08858557 24365.56806421
#    724.1945747    715.        ]
# 3次迭代: 适应值:0.337526,平均适应值:0.419047,最优结果:[16614.19959961 28352.25069502 48823.14887425 24164.28592269
#    724.2089686    720.        ]
# 4次迭代: 适应值:0.336651,平均适应值:0.433834,最优结果:[16649.44771819 28303.34387196 48838.40072488 24146.59616319
#    718.63710536   720.        ]
# 5次迭代: 适应值:0.333344,平均适应值:0.424685,最优结果:[16682.83623067 28341.86950935 48585.58535735 23853.37802788
#    715.33214143   722.        ]
# 6次迭代: 适应值:0.332025,平均适应值:0.415687,最优结果:[16679.78045525 28339.04866631 48487.49039994 23766.49124517
#    710.32805298   722.        ]
# 7次迭代: 适应值:0.331557,平均适应值:0.399230,最优结果:[16662.81151735 28329.5052992  48416.95989303 23713.34145823
#    709.80633128   722.        ]
# 8次迭代: 适应值:0.331197,平均适应值:0.396683,最优结果:[16652.40350373 28328.2120001  48358.27136924 23665.3384899
#    709.80633128   722.        ]
# 9次迭代: 适应值:0.331197,平均适应值:0.417546,最优结果:[16652.40350373 28328.2120001  48358.27136924 23665.3384899
#    709.80633128   722.        ]
# 10次迭代: 适应值:0.330794,平均适应值:0.415515,最优结果:[16690.04544651 28392.72478632 48322.55347062 23596.57478557
#    715.65913318   724.        ]
# 11次迭代: 适应值:0.330407,平均适应值:0.411758,最优结果:[16701.64313474 28411.76166419 48171.59372281 23409.72568911
#    723.27114282   724.        ]
# 12次迭代: 适应值:0.329501,平均适应值:0.401129,最优结果:[16701.64313474 28411.76166419 48152.79706675 23390.92903304
#    717.53361124   724.        ]
# 13次迭代: 适应值:0.328351,平均适应值:0.395214,最优结果:[16634.90906298 28333.12789857 48156.64322438 23472.20238103
#    701.83096931   723.        ]
# 14次迭代: 适应值:0.328100,平均适应值:0.391105,最优结果:[16684.49989789 28432.04727799 48066.38352918 23303.65665165
#    706.92395294   722.        ]
# 15次迭代: 适应值:0.327518,平均适应值:0.384427,最优结果:[16675.18049577 28416.34483065 47918.80329008 23171.78240111
#    709.97653337   722.        ]
# 16次迭代: 适应值:0.327093,平均适应值:0.393670,最优结果:[16679.44014891 28422.00770018 47905.29261212 23148.36357028
#    710.6133428    723.        ]
# 17次迭代: 适应值:0.326984,平均适应值:0.392279,最优结果:[16679.44014891 28422.00770018 47902.10856497 23145.17952312
#    709.97653337   723.        ]
# 18次迭代: 适应值:0.326984,平均适应值:0.386586,最优结果:[16679.44014891 28422.00770018 47902.10856497 23145.17952312
#    709.97653337   723.        ]
# 19次迭代: 适应值:0.326437,平均适应值:0.374954,最优结果:[16671.20798257 28407.27418823 47859.73487768 23116.739863
#    709.97653337   724.        ]
# 20次迭代: 适应值:0.326232,平均适应值:0.375968,最优结果:[16665.71052483 28399.97193055 47825.49654447 23089.3355865
#    709.97653337   724.        ]
# 21次迭代: 适应值:0.325548,平均适应值:0.376699,最优结果:[16659.99746974 28411.45780918 47781.52918257 23042.68016443
#    709.97653337   725.        ]
# 22次迭代: 适应值:0.325548,平均适应值:0.382243,最优结果:[16659.99746974 28411.45780918 47781.52918257 23042.68016443
#    709.97653337   725.        ]
# 23次迭代: 适应值:0.325548,平均适应值:0.391544,最优结果:[16659.99746974 28411.45780918 47781.52918257 23042.68016443
#    709.97653337   725.        ]
# 24次迭代: 适应值:0.325548,平均适应值:0.392217,最优结果:[16659.99746974 28411.45780918 47781.52918257 23042.68016443
#    709.97653337   725.        ]
# 25次迭代: 适应值:0.325253,平均适应值:0.379557,最优结果:[16672.69745908 28428.71561934 47650.36290849 22900.04399959
#    713.2814973    724.        ]
# 26次迭代: 适应值:0.324347,平均适应值:0.378492,最优结果:[16658.44953606 28409.70829871 47614.9080187  22882.46685345
#    709.97653337   725.        ]
# 27次迭代: 适应值:0.324347,平均适应值:0.388770,最优结果:[16658.44953606 28409.70829871 47614.9080187  22882.46685345
#    709.97653337   725.        ]
# 28次迭代: 适应值:0.323784,平均适应值:0.390028,最优结果:[16662.14114329 28407.5758017  47627.53826955 22896.4361093
#    709.97653337   727.        ]
# 29次迭代: 适应值:0.323055,平均适应值:0.392994,最优结果:[16653.0745919  28416.30700451 47573.37445351 22843.78449311
#    709.97653337   728.        ]
# 30次迭代: 适应值:0.323055,平均适应值:0.404278,最优结果:[16653.0745919  28416.30700451 47573.37445351 22843.78449311
#    709.97653337   728.        ]
# 31次迭代: 适应值:0.322731,平均适应值:0.389501,最优结果:[16644.13106873 28423.68576778 47435.35542624 22715.73964442
#    714.7495743    728.        ]
# 32次迭代: 适应值:0.321526,平均适应值:0.382540,最优结果:[16644.13106873 28423.68576778 47401.57028798 22681.95450616
#    707.61324047   728.        ]
# 33次迭代: 适应值:0.321526,平均适应值:0.382034,最优结果:[16644.13106873 28423.68576778 47401.57028798 22681.95450616
#    707.61324047   728.        ]
# 34次迭代: 适应值:0.321526,平均适应值:0.383557,最优结果:[16644.13106873 28423.68576778 47401.57028798 22681.95450616
#    707.61324047   728.        ]
# 35次迭代: 适应值:0.321070,平均适应值:0.369036,最优结果:[16638.34372534 28429.38105869 47385.7867919  22665.63813315
#    707.61324047   729.        ]
# 36次迭代: 适应值:0.321070,平均适应值:0.389671,最优结果:[16638.34372534 28429.38105869 47385.7867919  22665.63813315
#    707.61324047   729.        ]
# 37次迭代: 适应值:0.321025,平均适应值:0.369380,最优结果:[16645.2092669  28432.29753634 47381.27858349 22659.64847344
#    707.61324047   729.        ]
# 38次迭代: 适应值:0.321025,平均适应值:0.382943,最优结果:[16645.2092669  28432.29753634 47381.27858349 22659.64847344
#    707.61324047   729.        ]
# 39次迭代: 适应值:0.321025,平均适应值:0.389977,最优结果:[16645.2092669  28432.29753634 47381.27858349 22659.64847344
#    707.61324047   729.        ]
# 40次迭代: 适应值:0.320932,平均适应值:0.376434,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 41次迭代: 适应值:0.320932,平均适应值:0.370852,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 42次迭代: 适应值:0.320932,平均适应值:0.380579,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 43次迭代: 适应值:0.320932,平均适应值:0.369464,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 44次迭代: 适应值:0.320932,平均适应值:0.367875,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 45次迭代: 适应值:0.320932,平均适应值:0.366783,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 46次迭代: 适应值:0.320932,平均适应值:0.371900,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 47次迭代: 适应值:0.320932,平均适应值:0.386401,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 48次迭代: 适应值:0.320932,平均适应值:0.382129,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 49次迭代: 适应值:0.320932,平均适应值:0.372515,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 50次迭代: 适应值:0.320932,平均适应值:0.375028,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 51次迭代: 适应值:0.320932,平均适应值:0.382534,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 52次迭代: 适应值:0.320932,平均适应值:0.375040,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 53次迭代: 适应值:0.320932,平均适应值:0.377962,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 54次迭代: 适应值:0.320932,平均适应值:0.392190,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 55次迭代: 适应值:0.320932,平均适应值:0.377409,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 56次迭代: 适应值:0.320932,平均适应值:0.381562,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 57次迭代: 适应值:0.320932,平均适应值:0.374199,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 58次迭代: 适应值:0.320932,平均适应值:0.386415,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 59次迭代: 适应值:0.320932,平均适应值:0.367786,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 60次迭代: 适应值:0.320932,平均适应值:0.375484,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 61次迭代: 适应值:0.320932,平均适应值:0.379195,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 62次迭代: 适应值:0.320932,平均适应值:0.384238,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 63次迭代: 适应值:0.320932,平均适应值:0.372957,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 64次迭代: 适应值:0.320932,平均适应值:0.371008,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 65次迭代: 适应值:0.320932,平均适应值:0.382100,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 66次迭代: 适应值:0.320932,平均适应值:0.380037,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 67次迭代: 适应值:0.320932,平均适应值:0.389747,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 68次迭代: 适应值:0.320932,平均适应值:0.376459,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 69次迭代: 适应值:0.320932,平均适应值:0.375669,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 70次迭代: 适应值:0.320932,平均适应值:0.376651,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 71次迭代: 适应值:0.320932,平均适应值:0.386440,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 72次迭代: 适应值:0.320932,平均适应值:0.381881,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 73次迭代: 适应值:0.320932,平均适应值:0.390771,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 74次迭代: 适应值:0.320932,平均适应值:0.386528,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 75次迭代: 适应值:0.320932,平均适应值:0.373810,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 76次迭代: 适应值:0.320932,平均适应值:0.384156,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 77次迭代: 适应值:0.320932,平均适应值:0.380404,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 78次迭代: 适应值:0.320932,平均适应值:0.377934,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 79次迭代: 适应值:0.320932,平均适应值:0.381743,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 80次迭代: 适应值:0.320932,平均适应值:0.389345,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 81次迭代: 适应值:0.320932,平均适应值:0.377078,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 82次迭代: 适应值:0.320932,平均适应值:0.383797,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 83次迭代: 适应值:0.320932,平均适应值:0.366668,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 84次迭代: 适应值:0.320932,平均适应值:0.384022,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 85次迭代: 适应值:0.320932,平均适应值:0.368945,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 86次迭代: 适应值:0.320932,平均适应值:0.380373,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 87次迭代: 适应值:0.320932,平均适应值:0.380384,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 88次迭代: 适应值:0.320932,平均适应值:0.364922,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 89次迭代: 适应值:0.320932,平均适应值:0.369325,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 90次迭代: 适应值:0.320932,平均适应值:0.379871,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 91次迭代: 适应值:0.320932,平均适应值:0.379088,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 92次迭代: 适应值:0.320932,平均适应值:0.380541,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 93次迭代: 适应值:0.320932,平均适应值:0.387296,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 94次迭代: 适应值:0.320932,平均适应值:0.386842,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 95次迭代: 适应值:0.320932,平均适应值:0.373237,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 96次迭代: 适应值:0.320932,平均适应值:0.378385,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 97次迭代: 适应值:0.320932,平均适应值:0.378594,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 98次迭代: 适应值:0.320932,平均适应值:0.356374,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 99次迭代: 适应值:0.320932,平均适应值:0.374646,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 100次迭代: 适应值:0.320932,平均适应值:0.388583,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 101次迭代: 适应值:0.320932,平均适应值:0.384237,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 102次迭代: 适应值:0.320932,平均适应值:0.388701,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 103次迭代: 适应值:0.320932,平均适应值:0.378902,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 104次迭代: 适应值:0.320932,平均适应值:0.391650,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 105次迭代: 适应值:0.320932,平均适应值:0.376467,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 106次迭代: 适应值:0.320932,平均适应值:0.387973,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 107次迭代: 适应值:0.320932,平均适应值:0.368825,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 108次迭代: 适应值:0.320932,平均适应值:0.361080,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 109次迭代: 适应值:0.320932,平均适应值:0.375168,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 110次迭代: 适应值:0.320932,平均适应值:0.369754,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 111次迭代: 适应值:0.320932,平均适应值:0.376397,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 112次迭代: 适应值:0.320932,平均适应值:0.365496,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 113次迭代: 适应值:0.320932,平均适应值:0.364337,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 114次迭代: 适应值:0.320932,平均适应值:0.370930,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 115次迭代: 适应值:0.320932,平均适应值:0.368634,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 116次迭代: 适应值:0.320932,平均适应值:0.385800,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 117次迭代: 适应值:0.320932,平均适应值:0.380162,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 118次迭代: 适应值:0.320932,平均适应值:0.384346,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 119次迭代: 适应值:0.320932,平均适应值:0.378686,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 120次迭代: 适应值:0.320932,平均适应值:0.372965,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 121次迭代: 适应值:0.320932,平均适应值:0.376189,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 122次迭代: 适应值:0.320932,平均适应值:0.387545,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 123次迭代: 适应值:0.320932,平均适应值:0.386274,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 124次迭代: 适应值:0.320932,平均适应值:0.378521,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 125次迭代: 适应值:0.320932,平均适应值:0.370698,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 126次迭代: 适应值:0.320932,平均适应值:0.378714,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 127次迭代: 适应值:0.320932,平均适应值:0.382301,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 128次迭代: 适应值:0.320932,平均适应值:0.393591,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 129次迭代: 适应值:0.320932,平均适应值:0.371107,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 130次迭代: 适应值:0.320932,平均适应值:0.364190,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 131次迭代: 适应值:0.320932,平均适应值:0.367467,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 132次迭代: 适应值:0.320932,平均适应值:0.380080,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 133次迭代: 适应值:0.320932,平均适应值:0.372509,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 134次迭代: 适应值:0.320932,平均适应值:0.371736,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 135次迭代: 适应值:0.320932,平均适应值:0.388485,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 136次迭代: 适应值:0.320932,平均适应值:0.377760,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 137次迭代: 适应值:0.320932,平均适应值:0.351713,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 138次迭代: 适应值:0.320932,平均适应值:0.359225,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 139次迭代: 适应值:0.320932,平均适应值:0.367845,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 140次迭代: 适应值:0.320932,平均适应值:0.376541,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 141次迭代: 适应值:0.320932,平均适应值:0.377877,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 142次迭代: 适应值:0.320932,平均适应值:0.369615,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 143次迭代: 适应值:0.320932,平均适应值:0.373040,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 144次迭代: 适应值:0.320932,平均适应值:0.367125,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 145次迭代: 适应值:0.320932,平均适应值:0.378062,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 146次迭代: 适应值:0.320932,平均适应值:0.379019,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 147次迭代: 适应值:0.320932,平均适应值:0.363365,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 148次迭代: 适应值:0.320932,平均适应值:0.387934,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 149次迭代: 适应值:0.320932,平均适应值:0.378277,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 150次迭代: 适应值:0.320932,平均适应值:0.375307,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 151次迭代: 适应值:0.320932,平均适应值:0.375928,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 152次迭代: 适应值:0.320932,平均适应值:0.375816,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 153次迭代: 适应值:0.320932,平均适应值:0.382994,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 154次迭代: 适应值:0.320932,平均适应值:0.384730,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 155次迭代: 适应值:0.320932,平均适应值:0.363587,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 156次迭代: 适应值:0.320932,平均适应值:0.375619,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 157次迭代: 适应值:0.320932,平均适应值:0.366715,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 158次迭代: 适应值:0.320932,平均适应值:0.369658,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 159次迭代: 适应值:0.320932,平均适应值:0.388010,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 160次迭代: 适应值:0.320932,平均适应值:0.370449,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 161次迭代: 适应值:0.320932,平均适应值:0.380441,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 162次迭代: 适应值:0.320932,平均适应值:0.365124,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 163次迭代: 适应值:0.320932,平均适应值:0.381338,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 164次迭代: 适应值:0.320932,平均适应值:0.364321,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 165次迭代: 适应值:0.320932,平均适应值:0.381906,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 166次迭代: 适应值:0.320932,平均适应值:0.367807,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 167次迭代: 适应值:0.320932,平均适应值:0.368899,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 168次迭代: 适应值:0.320932,平均适应值:0.369864,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 169次迭代: 适应值:0.320932,平均适应值:0.373048,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 170次迭代: 适应值:0.320932,平均适应值:0.374604,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 171次迭代: 适应值:0.320932,平均适应值:0.387707,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 172次迭代: 适应值:0.320932,平均适应值:0.381375,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 173次迭代: 适应值:0.320932,平均适应值:0.383117,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 174次迭代: 适应值:0.320932,平均适应值:0.385173,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 175次迭代: 适应值:0.320932,平均适应值:0.398814,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 176次迭代: 适应值:0.320932,平均适应值:0.385431,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 177次迭代: 适应值:0.320932,平均适应值:0.374282,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 178次迭代: 适应值:0.320932,平均适应值:0.364038,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 179次迭代: 适应值:0.320932,平均适应值:0.373804,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 180次迭代: 适应值:0.320932,平均适应值:0.384245,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 181次迭代: 适应值:0.320932,平均适应值:0.378483,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 182次迭代: 适应值:0.320932,平均适应值:0.381067,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 183次迭代: 适应值:0.320932,平均适应值:0.382679,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 184次迭代: 适应值:0.320932,平均适应值:0.366570,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 185次迭代: 适应值:0.320932,平均适应值:0.373040,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 186次迭代: 适应值:0.320932,平均适应值:0.375347,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 187次迭代: 适应值:0.320932,平均适应值:0.372460,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 188次迭代: 适应值:0.320932,平均适应值:0.379824,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 189次迭代: 适应值:0.320932,平均适应值:0.367137,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 190次迭代: 适应值:0.320932,平均适应值:0.382872,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 191次迭代: 适应值:0.320932,平均适应值:0.367220,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 192次迭代: 适应值:0.320932,平均适应值:0.370811,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 193次迭代: 适应值:0.320932,平均适应值:0.358880,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 194次迭代: 适应值:0.320932,平均适应值:0.381801,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 195次迭代: 适应值:0.320932,平均适应值:0.370335,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 196次迭代: 适应值:0.320932,平均适应值:0.365771,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 197次迭代: 适应值:0.320932,平均适应值:0.364054,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 198次迭代: 适应值:0.320932,平均适应值:0.386436,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# 199次迭代: 适应值:0.320932,平均适应值:0.370780,最优结果:[16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# True Best Fitness: [16640.21086646 28427.27395912 47362.05787123 22647.23252056
#    707.61324047   729.        ]
# Best Fitness: 0.3209323756337901
# Average of queuing time (minute): 25.191582336555
# Average of idle time (minute): 4.162430826320832
# Number of charged EV within an hour: 729
# Total cost of all EV: 28427.27395912338
# Total revenue of EVCS: 16640.210866455636
# Time consuming: 519.3331174850464
